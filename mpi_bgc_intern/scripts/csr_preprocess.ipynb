# %% [markdown]
# ### CSR-Preprocessor:
#
# - Enter path to the prior and posterior file
# - choose an output path. For the file to be read by fluxy, these rules have to be followed: https://github.com/openghg/fluxy
# - Enter the correct species
#
# - If you choose co2 as species, you need to use the script "mpi_bgc_PARIS_inversion_results" as for now

# %% [markdown]
# 1. Create file for fluxy

# %%
import sys
import os
from utils import csr_preprocessor as prp
import xarray as xr

sys.path.append(os.path.abspath(".."))

##########
path_to_prior = "/path/to/prior"  # Path to Prior-File, example: "/work/bm1400/b301099/Input_Fluxy/pre_processor/Testdata/co2/Prior_vprm_flux_monthly_2006_2023_59_66km.nc"
path_to_posterior = "/path/to/posterior" # Path to Posterior-File, example: "/work/bm1400/b301099/Input_Fluxy/pre_processor/Testdata/co2/Posterior_vprm_flux_monthly_2006_2023_59_66km.nc"
path_to_output = "/path/to/ouput" # In order to be read by fluxy, the naming and storing convetions have to be followed (https://github.com/openghg/fluxy)
species = "species" #species of the flux in the file. For example "co2"
##########
    
prp.preprocess(path_to_prior, path_to_posterior, path_to_output, species)

# %% [markdown]
# #### 2. Prints available variables and dimensions

# %%
import xarray as xr
# Load the dataset
ds = xr.open_dataset(path_to_output)
# Show available variables and dimensions
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:               (longitude: 200, nv: 2, latitude: 160, time: 216,
#                            proc: 8, spec: 1)
# Coordinates:
#   * longitude             (longitude) float32 -14.88 -14.62 ... 34.62 34.88
#   * latitude              (latitude) float32 72.88 72.62 72.38 ... 33.38 33.12
#   * time                  (time) datetime64[ns] 2006-01-14T23:59:59 ... 2023-...
#   * proc                  (proc) int32 1 2 3 4 5 6 -2147483647 -2147483647
#   * spec                  (spec) int32 1
# Dimensions without coordinates: nv
# Data variables:
#     lon_bounds            (longitude, nv) float32 ...
#     lat_bounds            (latitude, nv) float32 ...
#     myear                 (time) float64 ...
#     dxyp                  (latitude, longitude) float32 ...
#     area                  (latitude, longitude) float32 ...
#     flux_total_prior      (time, latitude, longitude) float64 ...
#     flux_total_posterior  (time, latitude, longitude) float64 ...
# ...
