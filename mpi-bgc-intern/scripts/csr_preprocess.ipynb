# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from utils import csr_preprocessor as prp
import xarray as xr

path_to_prior = "/work/bm1400/b301035/ITMS/Deliverables/D-M.2.3-2024/D-M.2.3-2024.zip/Prior_vprm_flux_monthly_2006_2023_59_66km.nc"
path_to_posterior = "/work/bm1400/b301035/ITMS/Deliverables/D-M.2.3-2024/D-M.2.3-2024.zip/Posterior_vprm_flux_monthly_2006_2023_59_66km.nc"
path_to_output = "/work/bm1400/b301099/fluxy-mpi-bgc/mpi-bgc-intern/Output/Preprocessed_Output.nc"

prp.preprocess(path_to_prior, path_to_posterior, path_to_output)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/file_manager.py:210, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     209 try:
# --> 210     file = self._cache[self._key]
#     211 except KeyError:
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/work/bm1400/b301099/fluxy-mpi-bgc/mpi-bgc-intern/Output/Preprocessed_Output.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'a9aeddc8-dc8f-43c7-8164-c25fa5a3632b']
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 12
#       9 path_to_posterior = "/work/bm1400/b301035/ITMS/Deliverables/D-M.2.3-2024/D-M.2.3-2024.zip/Posterior_vprm_flux_monthly_2006_2023_59_66km.nc"
#      10 path_to_output = "/work/bm1400/b301099/fluxy-mpi-bgc/mpi-bgc-intern/Output/Preprocessed_Output.nc"
# ---> 12 prp.preprocess(path_to_prior, path_to_posterior, path_to_output)
#
# File /work/bm1400/b301099/fluxy-mpi-bgc/mpi-bgc-intern/utils/csr_preprocessor.py:32, in preprocess(path_to_prior, path_to_posterior, path_to_output)
#      24 ds = _combine_variable(ds, ds_posterior,
#      25                    varnames=["co2flux", "ch4flux"],
#      26                    new_prior_name="flux_total_prior_country",
#      27                    new_post_name="flux_total_posterior_country")
#      28 ds = _combine_variable(ds, ds_posterior,
#      29                    varnames=["co2flux_unc"],
#      30                    new_prior_name="stdevflux_total_prior_country",
#      31                    new_post_name="stdev_flux_total_posterior_country")
# ---> 32 ds.to_netcdf(path_to_output)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataset.py:1917, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1914     encoding = {}
#    1915 from xarray.backends.api import to_netcdf
# -> 1917 return to_netcdf(  # type: ignore  # mypy cannot resolve the overloads:(
#    1918     self,
#    1919     path,
#    1920     mode=mode,
#    1921     format=format,
#    1922     group=group,
#    1923     engine=engine,
#    1924     encoding=encoding,
#    1925     unlimited_dims=unlimited_dims,
#    1926     compute=compute,
#    1927     multifile=False,
#    1928     invalid_netcdf=invalid_netcdf,
#    1929 )
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/api.py:1199, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1195     else:
#    1196         raise ValueError(
#    1197             f"unrecognized option 'invalid_netcdf' for engine {engine}"
#    1198         )
# -> 1199 store = store_open(target, mode, format, group, **kwargs)
#    1201 if unlimited_dims is None:
#    1202     unlimited_dims = dataset.encoding.get("unlimited_dims", None)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:389, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     383 kwargs = dict(
#     384     clobber=clobber, diskless=diskless, persist=persist, format=format
#     385 )
#     386 manager = CachingFileManager(
#     387     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     388 )
# --> 389 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:336, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     334 self._group = group
#     335 self._mode = mode
# --> 336 self.format = self.ds.data_model
#     337 self._filename = self.ds.filepath()
#     338 self.is_remote = is_remote_uri(self._filename)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:398, in NetCDF4DataStore.ds(self)
#     396 @property
#     397 def ds(self):
# --> 398     return self._acquire()
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:392, in NetCDF4DataStore._acquire(self, needs_lock)
#     391 def _acquire(self, needs_lock=True):
# --> 392     with self._manager.acquire_context(needs_lock) as root:
#     393         ds = _nc4_require_group(root, self._group, self._mode)
#     394     return ds
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/file_manager.py:198, in CachingFileManager.acquire_context(self, needs_lock)
#     195 @contextlib.contextmanager
#     196 def acquire_context(self, needs_lock=True):
#     197     """Context manager for acquiring a file."""
# --> 198     file, cached = self._acquire_with_cache_info(needs_lock)
#     199     try:
#     200         yield file
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/backends/file_manager.py:216, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     214     kwargs = kwargs.copy()
#     215     kwargs["mode"] = self._mode
# --> 216 file = self._opener(*self._args, **kwargs)
#     217 if self._mode == "w":
#     218     # ensure file doesn't get overridden when opened again
#     219     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2353, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:1963, in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'/work/bm1400/b301099/fluxy-mpi-bgc/mpi-bgc-intern/Output/Preprocessed_Output.nc'

# %%
import xarray as xr

# Load the dataset
ds = xr.open_dataset(path_to_output)
# Show available variables and dimensions
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:               (longitude: 200, nv: 2, latitude: 160, time: 216,
#                            proc: 8, rt: 3, spec: 1)
# Coordinates:
#   * longitude             (longitude) float32 -14.88 -14.62 ... 34.62 34.88
#   * latitude              (latitude) float32 72.88 72.62 72.38 ... 33.38 33.12
#   * time                  (time) datetime64[ns] 2006-01-14T23:59:59 ... 2023-...
#   * proc                  (proc) int32 1 2 3 4 5 6 -2147483647 -2147483647
#   * rt                    (rt) int32 1 2 3
#   * spec                  (spec) int32 1
# Dimensions without coordinates: nv
# Data variables:
#     lon_bounds            (longitude, nv) float32 ...
#     lat_bounds            (latitude, nv) float32 ...
#     myear                 (time) float64 ...
#     lproc                 (proc) |S20 ...
#     lrt                   (rt) |S20 ...
#     lspec                 (spec) |S20 ...
#     dxyp                  (latitude, longitude) float32 ...
#     area                  (rt, latitude, longitude) float32 ...
#     co2flux_subt          (time, latitude, longitude) float32 ...
#     flux_total_prior      (time, latitude, longitude) float32 ...
#     flux_total_posterior  (time, latitude, longitude) float32 ...
# Attributes:
#     Title:         Jena CarboScope Regional results
#     History:       3nd Deliverables to ITMS, September 2024
#     Authors:       S. Munassar, F.-T. Koch, C. Gerbig
#     Institution:   MPI for Biogeochemistry, Jena
#     References:    Munassar et al., 2022, doi:10.5194/acp-22-7875-2022
#     Conventions:   CF-1.1
#     Species:       co2
#     valid_period:  2006_2023
#     dirname:       ~/INVERSION/OUTPUT/v2024/inv2006_2023/OUTPUT14.019r8t+stil...
#     filename:      Prior_vprm_flux_monthly_2006_2023_59_66km.nc
#     Comment:       NEE estimates derived from the Carboscope regional inversi...
