# %% [markdown]
# ## Test notebook to generate plots for annex

# %%
# %load_ext autoreload
# %autoreload 2
import annex_plot_generator
# Out:
# NOTE: If plotting units or scales look odd, edit species_info.json to fix this.
#
# Attempting to read data from intem_name_wetcharts_31sites_longrun
# Reading data from: /project/paris/inverse_modelling/InTEM/ch4/InTEM_NAME_EUROPE_EDGARWETCHART_longrun_33sites_intem_obs_intem_baseline_ch4_monthly.nc
# Done!
#
# Masking data from intem_name_wetcharts_31sites_longrun
# Scaling intem_name_wetcharts_31sites_longrun country fluxes by 28000000000.0
#
# Attempting to read data from intem_name_wetcharts_31sites
# Reading data from: /project/paris/inverse_modelling/InTEM/ch4/InTEM_NAME_EUROPE_EDGARWETCHART_31sites_intem_obs_intem_baseline_ch4_monthly.nc
# Done!
#
# Masking data from intem_name_wetcharts_31sites
# Scaling intem_name_wetcharts_31sites country fluxes by 28000000000.0
#
# Attempting to read data from elris_name_wetcharts_31sites
# Reading data from: /project/paris/inverse_modelling/ELRIS/ch4/ELRIS_NAME_EUROPE_EDGARWETCHART_31base_CH4_monthly.nc
# Done!
#
# ...
