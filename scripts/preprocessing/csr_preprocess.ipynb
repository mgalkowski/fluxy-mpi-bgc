# %% [markdown]
# ### CSR-Preprocessor:
#
# - Enter path to the prior and posterior file
# - choose an output path. For the file to be read by fluxy, these rules have to be followed: https://github.com/openghg/fluxy
# - Enter the correct species
#
# - If you choose co2 as species, you need to use the script "mpi_bgc_PARIS_inversion_results" as for now

# %% [markdown]
# #### 1. Create flux file for fluxy

# %%
import sys
import os
from scripts.preprocessing import csr_preprocessor as prp
import xarray as xr

sys.path.append(os.path.abspath(".."))

##########
path_to_prior = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn-unc100ger/PRI_flux_monthly.nc"  # Path to Prior-File
path_to_posterior = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn-unc100ger/mu1.0_100_flux_monthly.nc" # Path to Posterior-File
path_to_output = "/work/bm1400/b380914/projects/fluxy-mpi-bgc/data/tests/CSR/ch4/CSR_CH4_TEST_RHS_ch4_monthly.nc" # In order to be read by fluxy, the naming and storing convetions have to be followed (https://github.com/openghg/fluxy)
species = "ch4" #species of the flux in the file. For example "ch4", "co2"
##########
path_to_prior_country = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn-unc100ger/PRI_flux_monthly_EUROPE30f.nc" #other options: FLUXYALLf, FLUXYf
path_to_posterior_country = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn-unc100ger/mu1.0_100_flux_monthly_EUROPE30f.nc"
##########
path_to_uncertainty_country = "" # if no uncertainties (RHS results) are calculated
# provide the path to the RHS results (cross.* files) for each flux time step (e.g., month, year) in a list, 
# if no RHS results are available for a specific time step, enter "" in the list.
path_to_uncertainty_country = ["/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/rhs/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn_mu1._rhs=monthly+2021.04_EUROPE30f-unc100ger_2021jan/cross.rhs032_monthly+2021.04_EUROPE30f.d2",
                               "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/rhs/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn_mu1._rhs=monthly+2021.12_EUROPE30f-unc100ger_2021feb/cross.rhs032_monthly+2021.12_EUROPE30f.d2",
                               "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/rhs/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn_mu1._rhs=monthly+2023.80_EUROPE30f-unc100ger_2023oct/cross.rhs032_monthly+2023.80_EUROPE30f.d2",
                               "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/rhs/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn_mu1._rhs=monthly+2023.88_EUROPE30f-unc100ger_2023nov/cross.rhs032_monthly+2023.88_EUROPE30f.d2",
                               "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/rhs/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.Version_27082025_MDMunc21_3ch4rnsigsel.dualtracer_v2025.ATMv2025_uba8_20250908_ADJrn_mu1._rhs=monthly+2023.96_EUROPE30f-unc100ger_2023dec/cross.rhs032_monthly+2023.96_EUROPE30f.d2"          
                              ]


if os.path.exists(path_to_output):
    os.remove(path_to_output)

prp.preprocess(path_to_prior, path_to_posterior, path_to_prior_country, path_to_posterior_country, path_to_uncertainty_country, path_to_output, species)

# %% [markdown]
# #### 2. Prints available variables and dimensions

# %%
import xarray as xr
# Load the dataset
ds = xr.open_dataset(path_to_output)
# Show available variables and dimensions
print(ds)

# %% [markdown]
# #### 3. Create concentration file for fluxy

# %%
from scripts.preprocessing import csr_preprocessor_concentration as prpc

##########
path_to_prior_conc = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.---.dualtracer_v2025_Val_20s.ATMv2025_Valentin_prior_ld_oc_nofrac_ADJrn/PRI_output1.---.dualtracer_v2025_Val_20s/"
path_to_posterior_conc = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.---.dualtracer_v2025_Val_20s.ATMv2025_Valentin_prior_ld_oc_nofrac_ADJrn/mu1.0_100_output1.---.dualtracer_v2025_Val_20s/"
path_to_farfield_conc = "/work/mj0143/b380914/INVERSION/OUTPUT/ch4_rn_inversion/2021_2023_inversion/ch4_only_test/OUTPUT14.019r8+stilt.2021-2023_stilt04.ch4.---.dualtracer_v2025_Val_20s.ATMv2025_Valentin_prior_ld_oc_nofrac_ADJrn/input.---.dualtracer_v2025_Val_20s/"
path_to_output_conc = "/work/bm1400/b380914/projects/fluxy-mpi-bgc/data/tests/CSR/ch4/CSR_CH4_TEST_RHS_ch4_monthly_concentrations.nc"
##########
start_year = 2021 
end_year = 2023
species = "ch4" #species of the flux in the file. For example "ch4", "co2"
##########

if os.path.exists(path_to_output_conc):
    os.remove(path_to_output_conc)

prpc.preprocess_conc(path_to_prior_conc, path_to_posterior_conc, path_to_farfield_conc, path_to_output_conc, start_year, end_year, species)
