# %% [markdown]
# # Eddy flux
#
# This notebook shows how to plot eddy flux data with `fluxy`

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path
logging.basicConfig(level=logging.INFO)
logging.getLogger('matplotlib').setLevel(logging.WARNING)

from fluxy.config import set_print_settings
from fluxy.io import read_config_files
from fluxy.test_utils import data_dir
from fluxy.plots.mf_timeseries import plot_timeseries, plot_sites_timeseries
from fluxy.plots.ec_flux.sectorial_stack import plot_stacked
from fluxy.operators.sectors import group_sectors
from fluxy.operators.ecflux import  filter_ecflux 
from fluxy.operators.stats import  stats_observed_vs_simulated


import matplotlib.pyplot as plt
import xarray as xr
plt.style.use('default')


species = 'co2'

data_dir = data_dir / 'ecflux' 

config_dict = read_config_files()
config_dict.keys()

# %%
from fluxy.io import read_model_output


dss = read_model_output(
    data_dir=data_dir,
    file_type="eddy_flux",
    species=species, 
    models=['EDDY_HARDAU', "EDDY_HARDAU_STORAGE_2LAYERS"]

)
list(map(display, dss.values()))

# %%
fig = plot_timeseries(
    dss,
    species=species,
    site='HARDAU',
    include={
        #"ecflux_observed": "flux_observed_random_error",
        "ecflux_observed": None,
        "ecflux_prior": None,
        #"ecflux_observed_storage": None,
    },
    n_bins= 20,
    config_data=config_dict,

)

# %%
fig = plot_timeseries(
    dss,
    species='co2',
    site='HARDAU',
    include={
        #"ecflux_observed": "flux_observed_random_error",
        "ecflux_observed": None,
        #"ecflux_observed_storage": None,
    },
    n_bins= 20,
    histogram_type='violin',
    config_data=config_dict,


)

# %%
fig = plot_timeseries(
    dss,
    species=species,
    site='HARDAU',
    include={
        #"ecflux_observed": "flux_observed_random_error",
        "ecflux_prior": None,
        #"ecflux_observed_storage": None,
    },
    n_bins= 100,
    y_lim=(-20,100),
    histogram_type='violin',
    config_data=config_dict,


)

# %%
fig = plot_timeseries(
    dss,
    species='co2',
    site='HARDAU',
    include={
        #"ecflux_observed": "flux_observed_random_error",
        "ecflux_observed": None,
        #"ecflux_observed_storage": None,
    },
    n_bins= 100,
    histogram_type='violin',
    y_lim=(-20,100),
    config_data=config_dict,


)

# %% [markdown]
# ## Correlation plots

# %%
from fluxy.plots.correlation import plot_correlation
from fluxy.operators.flux_align_dataset import align_time


fig = plot_correlation(
    dss,
    variable="ecflux_observed_storage",
    style='density'
)

# %%
from fluxy.operators.flux_align_dataset import align_time

try:
    fig = plot_correlation(
        {'EDDY_HARDAU': dss['EDDY_HARDAU']},
        variable=["ecflux_observed_storage", "ecflux_observed"],
        style='density',
        oppose='variables',
        lims=(-40, 40)
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## Sectorial plots

# %%
dss = group_sectors(dss,sectors_config=config_dict['sectors'],)

# %%
dss.keys()

# %%
df_stats = stats_observed_vs_simulated(
    dss, 
    sim_var="ecflux_prior",
    obs_var="ecflux_observed"
)
df_stats

# %%
from fluxy.plots.stats import plot_stats


plot_stats(df_stats, species=species, plot_type='mean_and_std', variable='co2 flux [μmol m-2 s-1]')

# %%
for season in ['DJF', 'MAM', 'JJA', 'SON']:

    fig, ax = plot_stacked(
        dss['EDDY_HARDAU_STORAGE_2LAYERS'],
        sectors_config=config_dict['sectors'],
        season=season,
        area=True
        
    )
    fig, ax = plot_stacked(
        dss['EDDY_HARDAU'],
        sectors_config=config_dict['sectors'],
        season=season,
        area=True
        
    )

# %%
fig, ax = plot_stacked(
    dss['EDDY_HARDAU'],
    sectors_config=config_dict['sectors'],
    
)
fig, ax = plot_stacked(
    dss['EDDY_HARDAU_STORAGE_2LAYERS'],
    sectors_config=config_dict['sectors'],
    
)
